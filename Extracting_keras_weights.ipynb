# %% [markdown]
# <a href="https://colab.research.google.com/github/mashdas/Deep_Learning_101/blob/master/Extracting_keras_weights.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
##XOR op
import numpy as np

x=np.array([
            [0,0],[1,0],[0,1],[1,1]
])

y=np.array([0,1,1,0])

##Builing a NN

from keras.models import Sequential
from keras.layers.core import Dense,Activation
import numpy as np


model=Sequential()
model.add(Dense(2,input_dim=2,activation="relu"))
model.add(Dense(1))
model.compile(loss="mean_squared_error",optimizer="adam")
model.fit(x,y,verbose=1,epochs=100)
# Out:
# Using TensorFlow backend.
# Epoch 1/100
# 4/4 [==============================] - 0s 19ms/step - loss: 0.6472
# Epoch 2/100
# 4/4 [==============================] - 0s 384us/step - loss: 0.6452
# Epoch 3/100
# 4/4 [==============================] - 0s 630us/step - loss: 0.6434
# Epoch 4/100
# 4/4 [==============================] - 0s 499us/step - loss: 0.6415
# Epoch 5/100
# 4/4 [==============================] - 0s 429us/step - loss: 0.6396
# Epoch 6/100
# 4/4 [==============================] - 0s 1ms/step - loss: 0.6377
# Epoch 7/100
# 4/4 [==============================] - 0s 477us/step - loss: 0.6356
# Epoch 8/100
# 4/4 [==============================] - 0s 487us/step - loss: 0.6336
# Epoch 9/100
# 4/4 [==============================] - 0s 611us/step - loss: 0.6316
# Epoch 10/100
# 4/4 [==============================] - 0s 502us/step - loss: 0.6296
# Epoch 11/100
# 4/4 [==============================] - 0s 506us/step - loss: 0.6276
# Epoch 12/100
# ...

# %%
##Extracting them weights::

for layerNum,layer in enumerate(model.layers):
  weights=layer.get_weights()[0]
  biases=layer.get_weights()[1]

  for toNeuronNum,bias in enumerate(biases):
    print(f'{layerNum}B -> L{layerNum+1}N{toNeuronNum}:{bias}')
# Out:
# 0B -> L1N0:0.0
# 0B -> L1N1:-0.0933004766702652
# 1B -> L2N0:0.09592440724372864
